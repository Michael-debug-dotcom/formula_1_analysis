# %%
# import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read csv as dataframe

df = pd.read_csv(r'driver_standings.csv')

# %%
df.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
# drop columns

df = df.drop(columns='positionText')

# %%
df.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position  wins
# 0                  1      18         1    10.0         1     1
# 1                  2      18         2     8.0         2     0
# 2                  3      18         3     6.0         3     0
# 3                  4      18         4     5.0         4     0
# 4                  5      18         5     4.0         5     0

# %%
# check for duplicates

duplicates = df.duplicated()

# print duplicates

print('Duplicate rows:')
print(df[duplicates])
# Out:
# Duplicate rows:
# Empty DataFrame
# Columns: [driverStandingsId, raceId, driverId, points, position, wins]
# Index: []

# %%
df['points'] = df['points'].astype(str).str.replace('.', ',')

df.head()
# Out:
#    driverStandingsId  raceId  driverId points  position  wins
# 0                  1      18         1   10,0         1     1
# 1                  2      18         2    8,0         2     0
# 2                  3      18         3    6,0         3     0
# 3                  4      18         4    5,0         4     0
# 4                  5      18         5    4,0         5     0

# %%
df.to_csv(r'driver_standings.csv', index=False)
